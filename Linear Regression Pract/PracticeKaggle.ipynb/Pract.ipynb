# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Salary_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
plt.scatter(x=df['YearsExperience'],y=df['Salary'])

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_93dd4_row0_col0, #T_93dd4_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_93dd4_row0_col1, #T_93dd4_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_93dd4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93dd4_level0_col0" class="col_heading level0 col0" >YearsExperience</th>
#       <th id="T_93dd4_level0_col1" class="col_heading level0 col1" >Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93dd4_level0_row0" class="row_heading level0 row0" >YearsExperience</th>
#       <td id="T_93dd4_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_93dd4_row0_col1" class="data row0 col1" >0.978242</td>
#     </tr>
#     <tr>
#       <th id="T_93dd4_level0_row1" class="row_heading level0 row1" >Salary</th>
#       <td id="T_93dd4_row1_col0" class="data row1 col0" >0.978242</td>
#       <td id="T_93dd4_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
X=df[['YearsExperience']]

# %%
y=df.Salary.values
y
# Out:
# array([ 39344.,  46206.,  37732.,  43526.,  39892.,  56643.,  60151.,
#         54446.,  64446.,  57190.,  63219.,  55795.,  56958.,  57082.,
#         61112.,  67939.,  66030.,  83089.,  81364.,  93941.,  91739.,
#         98274., 101303., 113813., 109432., 105583., 116970., 112636.,
#        122392., 121873.])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
Linear=LinearRegression()

# %%
Admin@ttl7

# %%
Linear.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=Linear.predict(X_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2_score=r2_score(y_test,y_pred)
print(mae)
print(rmse)
print(r2_score)
# Out:
# 5161.3287104001765
# 6146.923007994572
# 0.9414466227178215

# %%
y_pred
# Out:
# array([115574.62288352,  71680.93878159, 102499.90847018,  75416.57147111,
#         55804.4998511 ,  60474.04071301, 122111.98009019, 107169.44933209,
#         63275.76523015])

# %%
Linear.predict([[6]])
# Out:
# c:\Users\ass931235\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([81020.0205054])

# %%
plt.scatter(x=df['YearsExperience'],y=df['Salary'])
plt.scatter(X_test,y_pred)

# %%
plt.scatter(x=df['YearsExperience'],y=df['Salary'])
plt.scatter(X,Linear.predict(X))
